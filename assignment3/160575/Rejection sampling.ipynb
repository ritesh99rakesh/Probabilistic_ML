# %% [markdown]
# # Rejection Sampling

# %% [markdown]
# **Import required libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
# %matplotlib inline

# %% [markdown]
# **Define a function Normal()**

# %%
def Normal(x, mu, sigma):
    return np.exp(-((x-mu)**2)/(2*sigma**2))/np.sqrt(2*np.pi*sigma**2)

# %% [markdown]
# **Define p'(x) using the above Normal function**

# %%
def p_(x):
    return Normal(x, 20, 10) + Normal(x, 50, 5) + Normal(x, 80, 20)

# %% [markdown]
# **Define q(x)**

# %%
def q(x):
    return Normal(x, 50, 30)

# %% [markdown]
# **Setting the range for x**

# %%
x_range = np.arange(-50, 120, 0.1)

# %% [markdown]
# **Finding M using p' and q**

# %%
M = np.max(p_(x_range)/q(x_range))

# %% [markdown]
# **Rejection sampling algorithm**

# %%
n_iters = 0
n_samples = 0
samples = []
while n_samples <= 10000:
    n_iters += 1
    z = np.random.normal(50, 30)
    u = np.random.uniform(0, M*q(z))
    if u <= p_(z):
        samples.append(z)
        n_samples += 1
        if n_samples % 100 == 0:
            print("=", end='')
# Out:
# ====================================================================================================

# %% [markdown]
# **Plot the samples**

# %%
plt.figure(figsize=(10,10))
plt.plot(x_range, p_(x_range))
plt.plot(x_range, q(x_range))
plt.legend(['p_(x)', 'q(x)'])
plt.savefig("rejection_basic.png")
plt.plot(x_range, M*q(x_range))
plt.legend(['p_(x)', 'q(x)', 'Mq(x)'])
plt.savefig("rejection_envelope.png")
plt.hist(samples, 100, density=True)
plt.legend(['p_(x)', 'q(x)', 'Mq(x)', 'samples'])
plt.savefig("rejection_samples.png")
plt.plot(x_range, 0.33*p_(x_range), color='black')
plt.legend(['p_(x)', 'q(x)', 'Mq(x)', 'p(x)', 'samples'])
plt.savefig('rejection_final.png')
plt.show()

# %% [markdown]
# **Acceptance rate**

# %%
print(" rate =", 100*n_samples/n_iters, "%")
# Out:
#  rate = 45.4095532146749 %
